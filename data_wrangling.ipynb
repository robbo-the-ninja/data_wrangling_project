# %% [markdown]
# # ¡Hola Roberto! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# Hola, Alejandro Castellanos. Gracias por tus buenas observaciones. Al graficar he visto datos y tendencias que de otra  manera hubiera sido imposible ver. A veces entre tantos datos me es difícil entender cómo podría sacar conclusiones, pero ya entiendo que si grafico más me será más fácil. Saludos.
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# ----

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Roberto en el análisis exploratorio de datos, demostraste una gran habilidad para manejar datos duplicados y faltantes, dejando los datasets en óptimas condiciones para las siguientes etapas de análisis. Has respondido acertadamente varias de las preguntas propuestas, aunque debes hacer ajustes en algunas de éstas con el fin de obtener los resultados esperados. Te deje comentarios específicos que te ayudarán a realizar las correcciones necesarias.
#
# Recuerda que el contexto del análisis de datos, es importante reconocer que nuestro cerebro humano enfrenta limitaciones naturales al procesar y comparar valores numéricos de gran magnitud, lo cual puede dificultar la comprensión efectiva de la información cuantitativa; por esta razón, te sugiero complemetar partes de tu análisis con diagramas, ya que esta herramienta visual transforma los datos numéricos abstractos en elementos gráficos que nuestro sistema cognitivo puede interpretar de manera más natural e intuitiva, permitiéndonos realizar comparaciones directas y facilitando la identificación de patrones, tendencias y diferencias significativas con un simple vistazo, lo que resultaría considerablemente más desafiante si solo trabajáramos con los números en su forma bruta. Te comparto una página que seguramente te servirá para identificar el tipo de gráfico que se dede usar de acuerdo a la naturaleza de los datos: [Data-To-Viz](https://www.data-to-viz.com/)
#
#
# No debes desanimarte, esto hace parte del proceso de aprendizaje y hasta el momento has demostrado un gran dominio en la manejo y análisis de datos, por lo que estoy seguro que podrás hacer los ajustes fácilmente.
#
# Estaré atento a tu próxima iteración 👀
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Roberto excelente trabajo con los ajustes! Tu proyecto ahora cumple con todos los objetivos propuestos. Me alegra que te hayan servido mis recomendaciones, una imagen siempre será una gran herramienta para analizar los datos 😀
#
#
# Estoy seguro de que lo que aprendiste aquí te será muy útil en futuros proyectos. ¡Éxito en tu próximo sprint! 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
# - Como plan de acción primero llamaré a la librería pandas, que con el método 'pd.read_csv()' me va a permitir crear DataFrames que almacenaré en varibles. Dentro de este método acomodaré la información al separarla por columnas cada que haya un punto y coma. Después de eso comenzaré a conocer cada set de datos con el método 'info()'. Y con 'print()' y '.head()' veré un poco del contenido de las filas.

# %%
# importar librerías
import pandas as pd

# %%
# leer conjuntos de datos en los DataFrames
orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
products = pd.read_csv('/datasets/products.csv', sep=';')
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
departments = pd.read_csv('/datasets/departments.csv', sep=';')
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %%
# mostrar información del DataFrame
orders.info()
print()
print(orders.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %%
# mostrar información del DataFrame
products.info()
print(products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
# mostrar información del DataFrame
aisles.info()
print(aisles.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# mostrar información del DataFrame
departments.info()
print(departments.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# mostrar información del DataFrame
order_products.info()
print(products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
# - Noto que los DataFrames tienen el mismo número de filas que de entradas, por lo cual aparentemente no hay datos nulos. También noté que muchos datos son de tipo int64, cuando podrían ser de tipo object, como los datos de las columnas que terminan en '_id' o que datos de tipo float64 podrían ser de tipo int64.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo importando las librerías y los datos del proyecto. Adicionalmente usaste correctamente las funciones `info` y `head`, esto te permite hacer una primera revisión de los datos, su estructura y contenido. Con esta información, podemos establecer una hoja de ruta para ajustar, modificar y analizar los datos de una manera adecuada.
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
# - Puedo usar 'astype('object')' para hacer las columnas de ID de tipo object, pues no haremos cálculos matemáticos con ellas.
# - Después con 'df.isna()' y '.sum()' voy a contar ausentes por columna.
# - Con '.duplicated()' and '.sum()' podré ver los duplicados y sumarlos.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados

print(orders['order_id'].duplicated().sum())
print()
print(orders[orders['order_id'].duplicated()])
# Out:
# 15
#
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
# - He encontrado 15 filas duplicadas. Comparten la misma hora y día. Pero por algún motivo solamente eso.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
#print(orders[orders['order_id'].duplicated()])
print()
print(orders[(orders['order_dow'] == 3) & (orders['order_hour_of_day'] == 2)])
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
# - Podría sugerir un error en el registro de los datos.

# %%
# Elimina los pedidos duplicados
orders = orders.drop_duplicates()

# %%
# Vuelve a verificar si hay filas duplicadas
print(orders.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
print(orders['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos:
# - Después de descubrir que los duplicados sólo cómo compartían la hora y el día los eliminé. Creo que esas compras sugieren un error en el registro de los datos.

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(products.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
print(products['department_id'].duplicated().sum())
# Out:
# 49673

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)

products['product_name'] = products['product_name'].str.upper()
print(products['product_name'].duplicated().sum())
# Out:
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes

# Filtramos y luego verificamos duplicados
duplicates_non_missing = products[products['product_name'].notna()]['product_name'].duplicated()

# Ver los duplicados
print(products[products['product_name'].notna()][duplicates_non_missing])
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  BIOTIN 1000 MCG        47
# 5455         5456                 GREEN TEA WITH GINSENG AND HONEY        96
# 5558         5559                           CREAM OF MUSHROOM SOUP        69
# 7558         7559                        CINNAMON ROLLS WITH ICING       105
# 9037         9038                           AMERICAN CHEESE SLICES        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - No hay mucho que decir. En el DataFrame 'products' esperaba encontrarme con muchas repeticiones de los nombres de los productos.

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(departments.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de productos
print(departments['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - El DataFrame departments no tiene duplicados. Se trata de un DataFrame pequeño, con dos columnas, y pocas filas.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(aisles.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
print(aisles['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Al igual que con el DataFrame 'departments' no hay mucho que ver en este DataFrame con pocos datos y ningún duplicado.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(order_products.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso

print(order_products['order_id'].duplicated().sum())
print(order_products['product_id'].duplicated().sum())
# Out:
# 4094961
# 4499434

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Si analizamos la columna 'order_id' o 'product_id' veremos muchos duplicados. Me resulta sospecho que haya tantos duplicados en 'order_id'.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo identificando y eliminando los datos duplicados presentes en los datasets. Este tipo de datos se presentan por errores a la hora de ingresar y consolidar la información, identificarlos y removerlos evita sesgos en los resultados, reduce el consumo innecesario de recursos y mejora la calidad de los análisis. Si hay datos repetidos, las estadísticas pueden distorsionarse, los modelos predictivos pueden entrenarse con información redundante y las visualizaciones pueden ser mostrar información engañosa. Además, mantener datos limpios facilita su interpretación y optimiza el rendimiento de los algoritmos, garantizando conclusiones más precisas y representativas.
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
# Primeor veré el número
print(products['product_name'].isna().sum())

# Muestra de las filas el valor es NaN
print(products[products['product_name'].isna()])
# Out:
# 1258
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Todos los Nan que muestra nuestro filtrado tienen el mismo 'department_id' y 'aisle_id'.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
# la respuesta a la pregunta es: sí, todos los nombres de productos ausentes están relacionados con el pasillo con ID 100.
# Podemos comprobarlo con una suma.

# Filtramos las filas de 'product_name' donde el valor es un ausente.
non_available_names = products[products['product_name'].isna()]

# Sometemos la nueva variable a una condición donde sumaremos los valores no iguales a 100 en la columna 'aisle_id'.
aisles_100_non_availables = (non_available_names['aisle_id'] != 100).sum()

# La suma debería ser igual a cero.
print(aisles_100_non_availables)
# Out:
# 0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Comprobamos que los ausentes de la columna 'product_name' sólo están presentes en ese pasillo. Algo ha ocurrido en el pasillo con ID 100. Tal vez algunos productos de ese pasillo no tenían un nombre asignado antes de ser vendidos.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
# Sí, todos los nombres de productos ausentes están relacionados con el 'department_id' 21.


# Haremos lo mismo que antes para comprobar: indexación y una suma.

# Usaremos la misma variable con los nombres NaN filtrados en la columna 'product_name'
non_available_names = products[products['product_name'].isna()]

# Hagamos lo mismo, una suma.
department_21 = (non_available_names['department_id'] != 21).sum()

# La suma debería dar cero.
print(department_21)
# Out:
# 0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Solamente hay nombres de productos ausentes en el 'department_id' con valor 21 y a su vez en la columna 'aisle_id' con valor 100. Eso indica un problema en ese departamento y pasillo. No parece ser una simple coincidencia.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.

# Filtremos las información de 'department_id' primero:

department_21_name = departments[departments['department_id'] == 21]
print(department_21_name)


print()

# Ahora filtremos e imprimamos el nombre de el pasillo 100.
aisle_100_name = aisles[aisles['aisle_id'] == 100]
print(aisle_100_name)
# Out:
#     department_id department
# 20             21    missing
#
#     aisle_id    aisle
# 99       100  missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Los nombres de los departamentos y pasillos no están disponibles. Ambos tienen un object llamado 'missing'. No tenemos idea del nombre del producto ni del departamento o pasillo.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')
print(products['product_name'].isna().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Estos valores ausentes o no disponibles sugieren errores desde el inicio del organizamiento de los productos y la zona a la que pertenecen. Como se trata de valores categóricos será mejor sustituirlos por el object 'Unknown'.

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print(orders.isna().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?

# Filtramos los valores Nan de la única columna con valores ausentes
missing_order_days = orders[orders['days_since_prior_order'].isna()]

# Identifica el primer pedido de cada cliente gracias a 'user_id'
first_orders = orders.drop_duplicates('user_id')

# Encuentra las filas que no sean el primer pedido
non_first_missing = missing_order_days[~missing_order_days['user_id'].isin(first_orders['user_id'])]

# Ver los resultados
print(non_first_missing)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - No hay ausentes que no sean el primer pedido del cliente, lo cual indica que no hay ausentes realmente en la columna 'days_since_prior_order' a pesar del primer resultado obtenido.

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(order_products.isna().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?

min_quantity = order_products['add_to_cart_order'].min()
max_quantity = order_products['add_to_cart_order'].max()

print(min_quantity)
print(max_quantity)
# Out:
# 1.0
# 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - No puedo deducir mucho de esos números hasta comprobar los ID de cada venta u usuario y su relación con esos números.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'

missing_add_to_cart_order = order_products[order_products['add_to_cart_order'].isna()]['order_id']

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?

# Contar cuántos productos tiene pedido con Nan
order_counts = order_products[order_products['order_id'].isin(missing_add_to_cart_order)].groupby('order_id')['product_id'].count()

print(order_counts.min() > 64)

# Agrupa todos los pedidos con datos ausentes por su ID de pedido.

# Agrupar los pedidos con valores ausentes
grouped_missing_orders = order_products[order_products['order_id'].isin(missing_add_to_cart_order)].groupby('order_id')

# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.

# Contar el número de productos en cada pedido con valores ausentes y obtener el mínimo
min_product_count = order_counts.min()
print(min_product_count)
# Out:
# True
# 65

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Ningún pedido con datos faltantes tiene menos de esa cantidad. Tal vez los pedidos de más de 64 no se pudieron registrar por su tamaño.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.

# Reemplazamos los ausentes por el valor '999' de tipo object.
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999).astype(int)

# Verificamos que no haya ausentes
print(order_products['add_to_cart_order'].isna().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Ahora podemos identificar con facilidad los ausentes de 'add_to_cart_order' con el número entero 999.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos.
# - Al parecer los pedidos con más de 64 pedidos tienen errores al ser procesados.
# - El departamento 21 y el pasillo 100 estaban relacionados. No se saben los nombres de algunos de sus productos. Eso podría indicar un lote de productos a los que no se les asignó nombre. Hay un problema en esa área.
# - Hemos lidiado con estos ausentes al usar el object 'Unknown' y el int '999'. Así serán identificados como ausentes con mayor facilidad.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo identificando y ajustando los valores faltantes. Esta etapa es esencial en cualquier proyecto relacionado con datos, ya que la presencia de datos faltantes puede distorsionar los resultados, generar sesgos y reducir la efectividad de los modelos predictivos e inclusive generar errores en los mismos. Si no se manejan adecuadamente, pueden llevar a conclusiones incorrectas o a la pérdida innecesaria de información valiosa. Dependiendo del contexto, se pueden eliminar, imputar con valores puntuales o estadísticos, o también es hacer una estimación con algoritmos avanzados, logrando de esta manera que los análisis sean más precisos, representativos y útiles para la toma de decisiones. Te comparto un artículo donde se explican varias de las metodologías que se pueden utilizar para [ajustar los datos faltantes](https://www.kaggle.com/code/parulpandey/a-guide-to-handling-missing-values-in-python)
#
# </div>

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
# Verificar si hay valores de 'order_hour_of_day' entre 0 y 23
invalid_order_hour = orders[(orders['order_hour_of_day'] < 0) | (orders['order_hour_of_day'] > 23)]

# Verificar si hay valores de 'order_dow' entre 0 y 6
invalid_order_dow = orders[(orders['order_dow'] < 0) | (orders['order_dow'] > 6)]

# %%
# Imprimir los resultados
print(invalid_order_hour)
print(invalid_order_dow)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Escribe aquí tus conclusiones.
# - Que haya haya como resultado DataFrames vacíos indica que los datos son sensibles.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo comprobando que los datos relacionados con la hora y el día de la semana están en un rango correcto. Hacer este tipo de validaciones es fundamental en el análisis de datos, ya que esto nos permite detectar de forma temprana posibles errores o inconsistencias que podrían afectar significativamente nuestros resultados y conclusiones posteriores.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
# Agrupar por 'order_hour_of_day' y contar los usuarios únicos ('user_id')
orders_by_hour = orders.groupby('order_hour_of_day')['user_id'].nunique()
print(orders_by_hour)
print(orders_by_hour.max())
# Out:
# order_hour_of_day
# 0      2991
# 1      1671
# 2       958
# 3       744
# 4       735
# 5      1281
# 6      3757
# 7     10993
# 8     20268
# 9     28112
# 10    32195
# 11    32660
# 12    31754
# 13    32433
# 14    32797
# 15    32894
# 16    31579
# 17    26825
# 18    21795
# 19    17026
# 20    12891
# 21     9806
# 22     7670
# 23     5167
# Name: user_id, dtype: int64
# 32894

# %%
# Graficado

import matplotlib.pyplot as plt

# Usaré un gráfico de barras.
orders_by_hour.plot(
    kind='bar',
    title='Number of orders per hour',
    xlabel='Hour',
    ylabel='Number of users',
    figsize=(10, 5)
)

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones.
# - La hora preferida de los usuarios para comprar es a las tres de la tarde y las horas cercanas a las tres de la tarde. En las madrugadas hay un menor número de personas haciendo compras.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Los valores son correctos. Sin embargo, recuerda que los seres humanos somos principalmente visuales. Por lo tanto, cuando manejes este tipo de información, una buena práctica es acompañarla de una gráfica. Esto facilita el estudio y el análisis de los datos.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Perfecto Roberto, ahora la información es más clara
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
# hacemos lo mismo de arriba, pero ahora en 'order_dow'
orders_by_day = orders.groupby('order_dow')['user_id'].nunique()
print(orders_by_day)
print(orders_by_day.max())
# Out:
# order_dow
# 0    57661
# 1    56479
# 2    48587
# 3    45331
# 4    44281
# 5    46127
# 6    45604
# Name: user_id, dtype: int64
# 57661

# %%
import matplotlib.pyplot as plt

# Graficar los pedidos por día en un gráfico de barras
orders_by_day.plot(
    kind='bar',
    title='Number of orders per day',
    xlabel='Day',
    ylabel='Number of users',
    figsize=(10, 5)
)

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones.
# - Los domingos son el día preferido. Es como si a partir de ese día las ventas empezaran a bajar gradualmente, aunque la diferencia no es tan marcada.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Acá aplica el mismo comentario anterior. Siempre será mejor mostrar este tipo de datos con una gráfica que solo con la tabla
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente Roberto
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
# Resumen estadístico de 'days_since_prior_order'
waiting_time = orders['days_since_prior_order'].describe()

# Ver el resultado
print(waiting_time)

# Contar con nunique() los usuarios con 0
users_zero_days = orders[orders['days_since_prior_order'] == 0]['user_id'].nunique()

# Contar con nunique() los usuarios con 30
users_thirty_days = orders[orders['days_since_prior_order'] == 30]['user_id'].nunique()

print(users_zero_days)
print(users_thirty_days)
# Out:
# count    450135.000000
# mean         11.101814
# std           9.190004
# min           0.000000
# 25%           4.000000
# 50%           7.000000
# 75%          15.000000
# max          30.000000
# Name: days_since_prior_order, dtype: float64
# 7532
# 44444

# %%
import matplotlib.pyplot as plt

# Contamos la frecuencia de los días que hay entre cada venta.
waiting_distribution = orders['days_since_prior_order'].value_counts().sort_index()


waiting_distribution.plot(
    kind='bar',
    title='Days between orders',
    xlabel='Days since last order',
    ylabel='Orders',
    figsize=(10, 5)
)


plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones:
# - La mediana es de 11 días. El mínimo es 0 y el máximo 30. Esto indica ventas en el mismo día, lo cual es normal. Un máximo de treinta días indica ventas mensuales. El número de usuarios con 30 días de diferencia entre commpras indica que muchas personas compran de forma mensual. También sabemos que hay muchas ventas con frecuencia semanal.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# En este caso los valores estadísticos que muestras se quedan cortos. Para esta pregunta puedes usar un diagrama de barras para mostrar todos los valores desde el valor 0 hasta 30
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Buen trabajo Roberto, aquí podemos identificar aspectos clave: los valores de 0 probablemente corresponden a clientes que realizaron más de un pedido en el mismo día. Muchos de los clientes hacen compras semanales (cada 7 días), y parece que una gran proporción de usuarios realiza compras mensuales (cada 30 días). Sin embargo, la tendencia decreciente en los últimos días podría indicar un error común al registrar los datos correspondientes al día 30, ya que, cuando no hay información disponible, algunos sistemas suelen asignar automáticamente el último valor de la serie de tiempo (última hora, último día de la semana, del mes o del año). Es un detalle importante a tener en cuenta para mejorar la precisión de los datos.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Filtramos las órdenes por día.
wednesday_orders = orders[orders['order_dow'] == 3]
saturday_orders = orders[orders['order_dow'] == 6]

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Contamos los valores de las órdenes filtradas que corresponden a los míercoles y domingos
wednesday_counts = wednesday_orders['order_hour_of_day'].value_counts()
saturday_counts = saturday_orders['order_hour_of_day'].value_counts()

# Graficamos la tabla orders_2 que contiene las variables filtradas y con los valores contados
orders_2 = pd.DataFrame({
    'wednesday_counts': wednesday_counts,
    'saturday_counts': saturday_counts
})

orders_2.plot(
    kind='bar',
    title='Number of orders per hour. Wednesday vs Saturday',
    xlabel='Hour of the day',
    ylabel='Number of orders',
    figsize=(10, 5)
)

plt.legend(['Wednesday', 'Saturday'])
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones.
# - No hay diferencias considerables en el número de pedidos según la hora entre los días miércoles y sábado. Las personas suelen hacer más compras en las últimas horas de la mañana y las primeras de la tarde en ambos días.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has hecho una comparativa muy acertada entre los conjuntos de datos. Algo interesante que podemos observar es que hay una pequeña caída en las órdenes entre las 11:00 y las 13:00 los miércoles, algo que no ocurre los sábados. Esta disminución podría estar relacionada con el hecho de que muchas personas no usan Instacart durante ese horario porque están ocupadas comiendo o haciendo otras actividades relacionadas con la hora del almuerzo.
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Contamos los pedidos
orders_per_user = orders['user_id'].value_counts()

# Contamos cuántos clientes hicieron el mismo número de pedidos
order_counts = orders_per_user.value_counts()

# Graficamos la distribución en un gráfico de barras
order_counts.plot(
    kind='bar',  
    title='Number of orders per customer',
    xlabel='Orders',
    ylabel='Customers',
    figsize=(10, 5),
)

# Mostramos el gráfico
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones.
# - La mayoría de clientes solamente compra una vez. La compañía podría trabajar en un programa de lealtad.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Usar este tipo de visualizaciones para mostrar la distribución de los datos es siempre una excelente decisión. En este caso, podemos observar que la mayoría de los clientes en el conjunto de datos han realizado entre 1 y 10 pedidos. Además, se nota un comportamiento de decrecimiento uniforme, lo cual es algo totalmente esperado cuando se analizan órdenes de compra.
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
# Contamos la cantidad de veces que cada producto aparece
product_counts = order_products['product_id'].value_counts()

# Obtenemos los Ids de los 20 productos más populares. 'value_counts' organiza los valores de mayor a menor según la frecuencia.
top_20_ids = product_counts.head(20)

# Ahora obtenemos los nombres de los productos
top_20_names = products[products['product_id'].isin(top_20_ids.index)]

# Combinamos los IDs
top_20 = top_20_names[['product_id', 'product_name']]


print(top_20)
# Out:
#        product_id              product_name
# 5875         5876             ORGANIC LEMON
# 8276         8277  APPLE HONEYCRISP ORGANIC
# 13175       13176    BAG OF ORGANIC BANANAS
# 16796       16797              STRAWBERRIES
# 21136       21137      ORGANIC STRAWBERRIES
# 21902       21903      ORGANIC BABY SPINACH
# 22934       22935      ORGANIC YELLOW ONION
# 24851       24852                    BANANA
# 24963       24964            ORGANIC GARLIC
# 26208       26209                     LIMES
# 27844       27845        ORGANIC WHOLE MILK
# 27965       27966       ORGANIC RASPBERRIES
# 28203       28204        ORGANIC FUJI APPLE
# 39274       39275       ORGANIC BLUEBERRIES
# 40705       40706    ORGANIC GRAPE TOMATOES
# 45006       45007          ORGANIC ZUCCHINI
# 47208       47209      ORGANIC HASS AVOCADO
# 47625       47626               LARGE LEMON
# 47765       47766           ORGANIC AVOCADO
# 49682       49683            CUCUMBER KIRBY

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Perfecto! Has identificado correctamente el Top 20 de los productos más populares. Podemos observar que plátanos, fresas, aguacates y limones están en lo más alto de la lista, lo que sugiere que estos artículos son los favoritos entre los clientes. Además, es interesante notar que los usuarios muestran una clara preferencia por los productos con etiquetas "Organic". Esto nos da una idea valiosa sobre las tendencias de consumo y las prioridades de los compradores.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones.
# - Comida sana, orgánica y nutritiva domina la lista.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
# Primero contamos cuántas veces aparece cada 'order_id' en la tabla order_products y lo almacenamos
order_sizes = order_products['order_id'].value_counts()
print(order_sizes)
# Out:
# 61355      127
# 3308010    115
# 2136777    108
# 171934     104
# 1959075     98
#           ...
# 54659        1
# 210431       1
# 1717983      1
# 1136563      1
# 8196         1
# Name: order_id, Length: 450046, dtype: int64

# %%
# Con base en la nueva variable podemos en un histograma ver la distribución. Como ya sabemos,
# la mayoría de personas comprar un producto por pedido.

from matplotlib import pyplot as plt

order_sizes.plot(
    kind='hist',  
    bins=30,     
    title='Order size frequency',
    figsize=(10, 5)
)

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones.
# - La mayoría de personas compra un producto por orden. La tienda podría aumentar sus ventas si logra un mayor número de ventas por orden.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Magnífico! La distribución que has encontrado nos permite identificar que los clientes suelen comprar pocas unidades en cada orden. Aunque si ajustas el histograma aumentando las columnas/bins podrás identifica que una orden típica contiene entre 5 y 6 artículos, lo que sugiere que los clientes prefieren hacer compras más frecuentes en lugar de acumular grandes cantidades de productos de una sola vez. Este patrón es muy útil para entender los hábitos de compra y podría indicar que los usuarios valoran la frescura o la conveniencia de adquirir productos según sus necesidades inmediatas.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
import pandas as pd

# La columna 'reordered' muestra con el valor 1 los productos reordenados. Hay que filtrarlos.
reordered_products = order_products[order_products['reordered'] == 1]

# Volveremos a usar 'value.counts()' que nos dará un Series organizado de los valores con más repeticiones.
reordered_counts = reordered_products['product_id'].value_counts()

# Obtenemos los 20 más reordenados
top_20_reordered_ids = reordered_counts.head(20)

# Obtenemos los nombres que están en la tabla 'products'
top_20_reordered_names = products[products['product_id'].isin(top_20_reordered_ids.index)]

# Combinamos los valores
top_20_reordered = top_20_reordered_names[['product_id', 'product_name']]

print(top_20_reordered)
# Out:
#        product_id              product_name
# 5875         5876             ORGANIC LEMON
# 8276         8277  APPLE HONEYCRISP ORGANIC
# 13175       13176    BAG OF ORGANIC BANANAS
# 16796       16797              STRAWBERRIES
# 21136       21137      ORGANIC STRAWBERRIES
# 21902       21903      ORGANIC BABY SPINACH
# 22934       22935      ORGANIC YELLOW ONION
# 24851       24852                    BANANA
# 24963       24964            ORGANIC GARLIC
# 26208       26209                     LIMES
# 27844       27845        ORGANIC WHOLE MILK
# 27965       27966       ORGANIC RASPBERRIES
# 28203       28204        ORGANIC FUJI APPLE
# 39274       39275       ORGANIC BLUEBERRIES
# 45006       45007          ORGANIC ZUCCHINI
# 47208       47209      ORGANIC HASS AVOCADO
# 47625       47626               LARGE LEMON
# 47765       47766           ORGANIC AVOCADO
# 49234       49235       ORGANIC HALF & HALF
# 49682       49683            CUCUMBER KIRBY

# %% [markdown]
# Escribe aquí tus conclusiones.
# - Muchos de los productos más reordenados son los mismos que eran los más vendidos en general, lo cual tiene sentido. Con base en esta información la tienda podría desarrollar estrategias para seguir vendiendo estos productos y vender más los menos vendidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Gran trabajo! Has identificado correctamente el Top 20 de productos que más se vuelven a pedir, y esta lista es muy similar a la que encontraste anteriormente. Podemos notar que los productos agrícolas y los lácteos son los que más se reordenan, lo cual tiene mucho sentido, ya que los productos perecederos suelen ser artículos de consumo frecuente. Esto refleja un patrón de compra coherente con las necesidades cotidianas de los clientes
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
# Contamos el total de pedidos de los productos
total_orders = order_products['product_id'].value_counts()

# Contamos cuántas veces se han pedido los productos reordenados unicamente
reordered_orders = order_products[order_products['reordered'] == 1]['product_id'].value_counts()

# Con una división obtenemos la proporción
proportion_reordered = reordered_orders / total_orders

# Mostramos la proporción ordenada con 'sort_values()'.
proportion_reordered = proportion_reordered.sort_values(ascending=False)

# Imprimimos
print(proportion_reordered.head(20))
# Out:
# 12038    1.0
# 1809     1.0
# 36122    1.0
# 3205     1.0
# 41901    1.0
# 46398    1.0
# 10378    1.0
# 31026    1.0
# 46437    1.0
# 20787    1.0
# 1814     1.0
# 46445    1.0
# 29168    1.0
# 25777    1.0
# 43895    1.0
# 31011    1.0
# 6490     1.0
# 1806     1.0
# 1805     1.0
# 16106    1.0
# Name: product_id, dtype: float64

# %%
import matplotlib.pyplot as plt


proportion_reordered.plot(
    kind='hist',
    bins=30,
    title='Reorder rate per product',
    figsize=(10, 5)
)


plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones.
# - Después de graficar con un histograma está claro que hay una propoción considerablemente alta en los productos que se vuelven a pedir, pero contrario a los datos de la tabla, puedo ver que la proporción no es tan alta como pensé inicialmente. Hay una mayor variación.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Has hecho un cálculo correcto, pero si te das cuenta estos datos no nos dicen mucho, por eso tu conclusión es tan corta. algo que puedes hacer acá es graficas con una histogrma los valores que calculaste y analizar el comportamiento de los mismos.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Esta información es muy útil, ya que los productos con tasas de reorden altas podrían considerarse esenciales en el inventario, asegurando su disponibilidad constante, mientras que los productos con tasas bajas podrían beneficiarse de descuentos para incentivar su recompra. Además, estos datos son ideales para construir modelos de predicción que ayuden a anticipar compras futuras y optimizar la gestión de stock.
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
# Con merge() unimos las columnas con las que vamos a trabajar.
merged_data = order_products.merge(orders[['order_id', 'user_id']], on='order_id', how='left')

# Ya agrupadas las columnas, las organizamos con base en 'user_id' y vemos el número de valores únicos en 'product_id'
user_orders = merged_data.groupby('user_id')['product_id'].nunique()

# Filtramos los reordenados y los contamos
reordered_products = merged_data[merged_data['reordered'] == 1].groupby('user_id')['product_id'].nunique()

# Calculamos la proporción
repeat_rate = reordered_products / user_orders

# Imprimimos
print(repeat_rate.head(20))
# Out:
# user_id
# 2     0.040000
# 4          NaN
# 5     0.666667
# 6          NaN
# 7     0.923077
# 11    0.200000
# 12    0.250000
# 13    0.611111
# 14    0.296296
# 15    0.750000
# 16    0.461538
# 17    0.575758
# 19    0.244444
# 20         NaN
# 21    0.421053
# 22    1.000000
# 24    0.500000
# 26    0.437500
# 27    0.652174
# 28    0.447368
# Name: product_id, dtype: float64

# %%
import matplotlib.pyplot as plt

# Eliminamos ausentes para la gráfica.
repeat_rate_no_nan = repeat_rate.dropna()

# Graficamos el histograma de la tasa de repetición de pedidos por usuario
repeat_rate_no_nan.plot(
    kind='hist',
    bins=30,
    title='Reorder rate per user',
    figsize=(10, 5)
)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones:
# - Así como hay quienes no han repetido, al clientes con proporciones muy altas. La tienda podría trabajar en que las personas vuelvan a comprar el mismo producto para aumentar las ventas.
#
# - Con la gráfica puedo ver que la tasa de repetición es alta en el extremo superior. Hay gente que pide mucho los mismos productos, sus favoritos. Otros clientes parecen comprar nuevos productos generalmente. Se puede trabajar en hacer que los clientes tengan productos favoritos y se vuelvan una compra segura.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Los valores obtenidos son correctos. No obstante, para esta pregunta puedes ralizar una aproximación similar al comentario anterior. De esta forma, estoy seguro que podrás obterner insights valiosos para darle mayor valor a la información obtenida.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2dsa Iteración)</b> <a class=“tocSkip”></a>
#
# Perfecto Roberto, aunque vemos una amplia distribución de valores, esta información es muy útil, ya que nos ayuda a identificar clientes leales que frecuentemente repiten sus compras, lo cual es clave para fidelizarlos. Además, puede ser fundamental para diseñar estrategias de marketing dirigidas a aumentar la tasa de reorden en aquellos clientes con porcentajes más bajos, incentivándolos a comprar con mayor frecuencia.
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
# Filtrar los primeros añadidos basandonos en que los número sindican un orden secuencial.
first_items = order_products[order_products['add_to_cart_order'] == 1]

# ya filtrado, contamos cuantas veces aparece en 'product_id'
first_item_counts = first_items['product_id'].value_counts()

# Ya filtrados y organizados los almacenamos
top_20_first_items = first_item_counts.head(20)

# Debemos obtener sus nombres de otra columna de otra tabla. Para que todo esté organizado y coincida usaremos .index.
top_20_first_items_names = products[products['product_id'].isin(top_20_first_items.index)]

# Combinamos los resultados al mostrar ambas conlumnas juntas.
top_20_first_items_result = top_20_first_items_names[['product_id', 'product_name']]

# Imprimimos
print(top_20_first_items_result)
# Out:
#        product_id                 product_name
# 195           196                         SODA
# 5784         5785  ORGANIC REDUCED FAT 2% MILK
# 12340       12341                HASS AVOCADOS
# 13175       13176       BAG OF ORGANIC BANANAS
# 16796       16797                 STRAWBERRIES
# 19659       19660                 SPRING WATER
# 21136       21137         ORGANIC STRAWBERRIES
# 21902       21903         ORGANIC BABY SPINACH
# 22934       22935         ORGANIC YELLOW ONION
# 24851       24852                       BANANA
# 26208       26209                        LIMES
# 27085       27086                  HALF & HALF
# 27844       27845           ORGANIC WHOLE MILK
# 27965       27966          ORGANIC RASPBERRIES
# 38688       38689     ORGANIC REDUCED FAT MILK
# 44631       44632   SPARKLING WATER GRAPEFRUIT
# 47208       47209         ORGANIC HASS AVOCADO
# 47625       47626                  LARGE LEMON
# 47765       47766              ORGANIC AVOCADO
# ...

# %% [markdown]
# Escribe aquí tus conclusiones.
#
# Muchos de los artículos agregados al inicio son de los más vendidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Excelente trabajo al encontrar el Top 20 de productos que son agregados inicialmente a los carritos de compras! Podemos observar que se mantiene una tendencia clara: los productos frescos, especialmente las frutas, suelen ser los primeros en ser agregados al carrito. Además, los productos orgánicos tienen una fuerte presencia en esta lista, y los artículos básicos de alimentación funcionan como "productos ancla" que inician las sesiones de compra. Esta información es muy valiosa, ya que puede ayudarnos a diseñar la disposición de la tienda en línea, planificar el inventario, crear estrategias de marketing más efectivas y optimizar la experiencia de compra en línea.
#
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Hay una marcada preferencia por ciertos productos, los cuales son reordenados mucho, se añaden primero al carrito y se venden mucho en general.
#
# También sabemos que hay se compra una cantidad relativamente baja de productos. La tienda podría trabajar en que se compren más productos por carrito.
#
# Con las proporciones de repetición de productos comprados podemos ver cuáles clientes son los más leales, que han encontrado en la tienda un espacio dónde comprar sus productos preferidos con regularidad.
#
# Al saber qué tipos de productos se venden más se puede potenciar su venta con descuentos, venta cruzada, promociones, etc.
#
# Había un lote de productos sin nombre asociado a una área en particular.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu conclusión general destaca aspectos clave del comportamiento del cliente y las oportunidades de mejora en la estrategia de ventas. Has identificado de manera acertada la preferencia marcada por ciertos productos, lo que sugiere una lealtad del cliente hacia artículos específicos y la posibilidad de potenciar su venta mediante estrategias como descuentos o promociones. Además, señalas una oportunidad clara para incrementar el volumen de productos por carrito, lo que podría fortalecer el valor promedio de compra. La observación sobre los clientes más leales y su relación con los productos que compran regularmente es un hallazgo valioso, ya que permite diseñar iniciativas para retener y fidelizar a este segmento.
# </div>
